# %%
from IPython.display import display, Image, Audio

import cv2  # We're using OpenCV to read video, to install !pip install opencv-python
import base64
import time
from openai import OpenAI
import os
import requests

# %%
from IPython.display import display, Image, Audio

import cv2  # We're using OpenCV to read video, to install !pip install opencv-python
import base64
import time
from openai import OpenAI
import os
import requests

client = OpenAI(api_key=os.environ.get("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",
                                       "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"))

# %%
video = cv2.VideoCapture("data/caltrikzz_mj2.mp4")

base64Frames = []
while video.isOpened():
    success, frame = video.read()
    if not success:
        break
    _, buffer = cv2.imencode(".jpg", frame)
    base64Frames.append(base64.b64encode(buffer).decode("utf-8"))

video.release()
print(len(base64Frames), "frames read.")
# Out:
# 490 frames read.

# %%
len( base64Frames[0] )
# Out:
# 409932

# %%
len( base64Frames[0::100] )
# Out:
# 9

# %%
#overall, we are testing the presence of 5 themes specified in this folder: 
#https://drive.google.com/drive/folders/1YUnGSuXfeF2Jk1SDoP1Hymul7EU_a8Ai
#1. vaping products (e-cigarettes), 2. marijuana, 3. health, 4. fashion and 5. technology

#1.Specific vape products + one of the themes of interest (with probabilities per frame) - this could be a separate tasks
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also provide the probability that there is vaping pod device in each frame. "+
            "Please also provide the probability that there is vaping mod device in each frame. "+
             "Please also provide the probability that there is each juice in any frame. What flavor it is? "+
             "Please provide the probability that there is active lifestyle in each frame.  "+
             "Limit the description to 20 words per frame"),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 1500,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# 1. **Frame 1 -** Young man in black outfit standing, holding a potential vaping device. No visible exercise.
#    - **Vaping Pod Device:** Low (25%)
#    - **Vaping Mod Device:** Low (25%)
#    - **E-juice Present:** No (0%)
#    - **Active Lifestyle:** Low (20%)
#
# 2. **Frame 2 -** Young man strolling outside a building, looking up. No visible activity or devices.
#    - **Vaping Pod Device:** No (0%)
#    - **Vaping Mod Device:** No (0%)
#    - **E-juice Present:** No (0%)
#    - **Active Lifestyle:** Moderate (50%)
#
# 3. **Frame 3 -** Man walking casually near a building. No devices visible.
#    - **Vaping Pod Device:** No (0%)
#    - **Vaping Mod Device:** No (0%)
#    - **E-juice Present:** No (0%)
#    - **Active Lifestyle:** Moderate (50%)
#
# 4. **Frame 4 -** Young man pacing by a window, no visible vaping activity.
#    - **Vaping Pod Device:** No (0%)
#    - **Vaping Mod Device:** No (0%)
#    - **E-juice Present:** No (0%)
#    - **Active Lifestyle:** Low (20%)
#
# ...

# %%
#the following 8 prompts are different versions from which we could choose one - the best performer. 
#2.Specific themes of interests (with probabilities per frame)

PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also provide the probability that there is vaping in each frame. "+
             "Please also provide the probability that there is marijuana in each frame. "+
            "Please provide the probability that there is fashion in each frame.  "+
             "Please provide the probability that there is entertainment in each frame.  "+
             "Please provide the probability that there is technology in each frame.  "+
             "Please provide the probability that there is active lifestyle in each frame.  "+
             "Limit the description to 20 words per frame"),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# 1. **Frame Description:** Man standing outside a building, holding a vape device in hands.
#    - **Vaping:** High (90%)
#    - **Marijuana:** Low (5%)
#    - **Fashion:** Moderate (50%)
#    - **Entertainment:** Low (20%)
#    - **Technology:** Moderate (50%)
#    - **Active Lifestyle:** Low (10%)
#
# 2. **Frame Description:** Man is walking outside, looking upwards, subtropical plants in background.
#    - **Vaping:** Low (10%)
#    - **Marijuana:** Low (5%)
#    - **Fashion:** Moderate (50%)
#    - **Entertainment:** Low (20%)
#    - **Technology:** Low (10%)
#    - **Active Lifestyle:** Moderate (40%)
#
# 3. **Frame Description:** Man walking past a large window, looking towards the ground.
#    - **Vaping:** Low (10%)
#    - **Marijuana:** Low (5%)
#    - **Fashion:** Moderate (50%)
#    - **Entertainment:** Low (20%)
#    - **Technology:** Low (10%)
#    - **Active Lifestyle:** Moderate (40%)
#
# ...

# %%
#3.Themes of interest (with descriptions per frame)
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in each frame. "+
             "Please also descirble if there is marijuana in each frame. "+
            "Please also descirble if there is  fashion in each frame.  "+
             "Please also descirble if there is technology in each frame.  "+
             "Please also descirble if there is active lifestyle in each frame.  "+
             "Limit the description to 20 words per frame"),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# 1. Man standing, holding a device, sunny day. No vaping or marijuana. Fashion visible. No technology or active lifestyle.
# 2. Man looking upwards, sunny background. No vaping or marijuana. Fashion visible. No technology or active lifestyle.
# 3. Man walking, urban outdoor setting. No vaping or marijuana. Fashion visible. No technology or active lifestyle.
# 4. Man adjusting something on chest, neutral backdrop. No vaping or marijuana. Fashion visible. No technology or active lifestyle.
# 5. Man standing, smiling, night time setting. No vaping or marijuana. Fashion visible. No technology or active lifestyle.
# 6. Man presenting a vape juice bottle. No marijuana. Fashion visible. Vaping-related technology. No active lifestyle.
# 7. Man exhaling vapor, holding a vaping device and bottle. No marijuana. Fashion visible. Vaping and technology. No active lifestyle.
# ...

# %%
#4.Specific themes of interests (with descriptions per video), limited to 20 words
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. "+
             "Please also descirble if there is marijuana  in this video. "+
            "Please also descirble if there is fashion  in this video.  "+
             "Please also descirble if there is entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology  in this video.  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Limit the description to 20 words"),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vg/3cf9qspx1svgwy0h_n379frh0000gn/T/ipykernel_62767/547440192.py in <module>
#      11              "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
#      12              "Limit the description to 20 words"),
# ---> 13             *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
#      14         ],
#      15     },
#
# NameError: name 'base64Frames' is not defined

# %%
#5.Specific themes of interests (with descriptions per video), include a brand name, + 
#marijuana with specifying presence of THC or CBD
#limited to 50 words, separated by $ 
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. Inlcude a brand name "+
             "Please also descirble if there is cannabis, THC or CBD product in this video.Inlcude a brand name"+
            "Please also descirble if there is  fashion  in this video.  "+
             "Please also descirble if there is  entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology  in this video.  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Limit the description to 50 words" 
            "please format the results separating the promt with a dollar sign"
            
            ),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# $Vaping$ Yes, the video features vaping.
# $Cannabis, THC or CBD product$ No visible indication of cannabis, THC, or CBD products.
# $Brand name$ Shown brands include "Eighty Six."
# $Fashion$ No explicit focus on fashion.
# $Entertainment$ No entertainment like DJ or videogames evident.
# $Technology$ Vaping devices are technological items highlighted.
# $Active lifestyle$ No active lifestyle or sports content evident.
# $Limit to 50 words$ Video shows a person with vaping devices, highlighting brand "Eighty Six." No cannabis, fashion, entertainment, or sports content. Focus is on the technology of vaping.

# %%
#6.Specific themes of interests, 
#limited to 50 words, separated by $ (for a better structure)

#Areas for imporvement:
#**Active Lifestyle:** Not depicted in the video frames - this seems hard to interpret. 
#Need to specify in the promt to include in the output "yes" if present or "no" if not present 
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. "+
             "Please also descirble if there is cannabis, THC or CBD product in this video."+
            "Please also descirble if there is  fashion  in this video.  "+
             "Please also descirble if there is  entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology (not vaping-related) in this video.  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Limit the description to 50 words" 
            "please format the results separating the promt with a dollar sign"
        
            ),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# **Vaping:** Yes, the video shows a person vaping. $
# **Cannabis/THC/CBD:** Yes, the product label indicates THC content. $
# **Brand Name:** 'Rolex' is visible on the product packaging. $
# **Fashion:** Yes, the person is wearing a vibrant, colorful jacket. $
# **Entertainment:** Not visible in the frames provided. $
# **Technology:** Yes, involves the use of a vaping device. $
# **Active Lifestyle:** Not depicted in the video frames.

# %%
#7.Specific themes of interests (with descriptions per video), limited to 20 words - this one is the same as prompt 4, 
#but specifies THC or CBD.
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. "+
             "Please also descirble if there is cannabis, THC or CBD product in this video."+
            "Please also descirble if there is  fashion  in this video.  "+
             "Please also descirble if there is  entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology in this video (do not include vaping).  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Limit the description to 20 words" 
            
        
            ),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)

# %%
#8.Specific themes of interests (with descriptions per video), limited to 50 words 
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. "+
             "Please also descirble if there is cannabis, THC or CBD product in this video."+
            "Please also descirble if there is  fashion  in this video.  "+
             "Please also descirble if there is  entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology in this video (do not include vaping).  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Limit the description to 50 words" 
            
        
            ),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# The video involves a person vaping and holding a THC/CBD product package, suggesting cannabis use. The person wears a vibrant, colorful jacket, adding a fashion element. There are no indications of sports, entertainment, or other forms of technology beyond the vaping device.

# %%
#9.Specific themes of interests (with descriptions per video), limited to 100 words
PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            ("These are frames from a video that I want to upload. Describe what is in this video. "+
            "Please also descirble if there is vaping in this video. "+
             "Please also descirble if there is cannabis, THC or CBD product in this video."+
            "Please also descirble if there is  fashion  in this video.  "+
             "Please also descirble if there is  entertainment (for example, dj, videogames)  in this video.  "+
             "Please also descirble if there is technology in this video (do not include vaping).  "+
             "Please also descirble if there is active lifestyle (for example sport) in this video.  "+
             "Is there anything else in this video?"
             "Limit the description to 100 words" 
            
        
            ),
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::100]),
        ],
    },
]

params = {
    "model": "gpt-4-turbo",
    "messages": PROMPT_MESSAGES,
    "max_tokens": 2000,
}

result = client.chat.completions.create(**params)
print(result.choices[0].message.content)
# Out:
# The video features a man vaping from a vape pen, which appears to contain a THC or CBD product given the packaging labeled "THC." He is wearing vibrant, multicolored attire that displays distinctive street fashion. Throughout different frames, he demonstrates the activation and inhalation from the vape pen, exhales vapor, and interacts closely with the camera. No obvious elements of entertainment like gaming or DJs, active lifestyle activities, or other technology besides the vape pen are visible. The focus seems primarily on the act of vaping and the style of the individual.

# %%
#loop for reading in multiple images - this is not working, need to fix
import os
import cv2


# Specify the directory containing the video files
video_directory = 'data/*.mp4'

# List all files in the directory
files = os.listdir(video_directory)

# Loop over each file in the directory
for filename in files:
    # Check if the file is a video (you might need to adjust the extensions depending on your files)
    if filename.endswith('.mp4') or filename.endswith('.avi') or filename.endswith('.png'):
        # Construct the full path to the video file
        video_path = os.path.join(video_directory, filename)
        
        # Create a video capture object with the video file
        cap = cv2.VideoCapture(video_path)
        
        # Check if the video was opened successfully
        if not cap.isOpened():
            print(f"Error opening video file {video_path}")
            continue

        # Read frames in a loop until the end of the video
        while True:
            ret, frame = cap.read()  # Read a frame from the video
            if not ret:
                print("Finished reading the video file or error occurred")
                break

            # You can process the frame here
            # cv2.imshow('Frame', frame)  # Display the frame (Uncomment this line to see the video frames)

            # Press 'Q' to exit the loop early (if displaying frames)
            # if cv2.waitKey(1) & 0xFF == ord('q'):
            #     break
        
        # Release the video capture object
        cap.release()
        print(f"Completed reading video: {filename}")

# cv2.destroyAllWindows()  # Uncomment if using cv2.imshow
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/vg/3cf9qspx1svgwy0h_n379frh0000gn/T/ipykernel_47905/1319017414.py in <module>
#       8
#       9 # List all files in the directory
# ---> 10 files = os.listdir(video_directory)
#      11
#      12 # Loop over each file in the directory
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/*.mp4'
